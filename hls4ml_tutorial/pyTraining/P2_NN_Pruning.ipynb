# %% [markdown]
# # Red Neuronal para discriminacion de Gamma/Neutron
#
# Se creara una red neuronal que discrimine entre Gamma y Neutrones a partir de sus trazas de evento, esto a traves de Machine Learning implementado en la FPGA
#
# *Código adaptado por:* Fabian Castaño
#
# ---
#
# ## Entrenamiento
# Este entrenamiento se realizará basado en el trabajo previo:
# - Workflow based on R. S. Molina, I. R. Morales, M. L. Crespo, V. G. Costa, S. Carrato and G. Ramponi, "An End-to-End Workflow to Efficiently Compress and Deploy DNN Classifiers on SoC/FPGA", in IEEE Embedded Systems Letters, vol. 16, no. 3, pp. 255-258, Sept. 2024, doi: 10.1109/LES.2023.3343030.
# - Code adapted from the official repository of "An End-to-End Workflow to Efficiently Compress and Deploy DNN Classifiers on SoC/FPGA"
# - Using open dataset from: https://doi.org/10.5281/zenodo.8037058

# %% [markdown]
# ### Librerias

# %%
import os
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# Tensorflow and Keras imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l2, l1

import tensorflow_model_optimization as tfmot

# Pruning API
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_schedule, pruning_callbacks
from tensorflow_model_optimization.sparsity.keras import strip_pruning

# Quantization API
from qkeras import *

# Knowledge Distillation
from src.distillationClassKeras import *

# Metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import shuffle

# Pre-processing
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder

# Training utils
from sklearn.model_selection import train_test_split

tf.random.set_seed(42)
np.random.seed(42)

# %%
# Function to define the training and testing datasets

def preproc_dataset(signal_dfN, signal_dfG,
                    train_size=9000,
                    test_size=1000,
                    seed=42):

    LABEL = "class"

    # shuffle reproducible
    signal_dfN = shuffle(signal_dfN, random_state=seed)
    signal_dfG = shuffle(signal_dfG, random_state=seed)

    # seleccionar tamaños iguales
    train_neutron = signal_dfN.iloc[:train_size]
    test_neutron  = signal_dfN.iloc[train_size:train_size+test_size]

    train_gamma = signal_dfG.iloc[:train_size]
    test_gamma  = signal_dfG.iloc[train_size:train_size+test_size]

    # combinar
    dfTrain = pd.concat([train_neutron, train_gamma])
    dfTest  = pd.concat([test_neutron, test_gamma])

    # mezclar final
    dfTrain = shuffle(dfTrain, random_state=seed).reset_index(drop=True)
    dfTest  = shuffle(dfTest, random_state=seed).reset_index(drop=True)

    # ---------- NORMALIZACION (CRITICO PARA HLS) ----------

    features = dfTrain.columns[:-1]

    dfTrain[features] = dfTrain[features] / 512.0
    dfTest[features]  = dfTest[features] / 512.0

    return dfTrain, dfTest

# %% [markdown]
# ### Carga de datos

# %%
# Define paths
PATH = "dataset/"

TRAIN_DATASET_FILE = PATH + "train_dataset.csv"
TEST_DATASET_FILE  = PATH + "test_dataset.csv"

# Load datasets
dfTrain = pd.read_csv(TRAIN_DATASET_FILE)
dfTestGN = pd.read_csv(TEST_DATASET_FILE)

# Separate classes
dfGamma = dfTrain[dfTrain["class"] == 0]
dfNeutron = dfTrain[dfTrain["class"] == 1]

# %% [markdown]
# ### Preprocesamiento y separacion de dataset
#
# Separacion del dataset en datos de entrenamiento y de test

# %%
# Pre-processing dataset for training
df_train, dfTest = preproc_dataset(dfNeutron, dfGamma)

# Save the test
# dfTest.to_csv('dataset/test.csv')

df_train_ = df_train.pop('class')
dfTest_   = dfTest.pop('class')

# One-hot encoder
le = LabelEncoder()
y = le.fit_transform(df_train_)
y = to_categorical(y, 2)

le = LabelEncoder()
yTest = le.fit_transform(dfTest_)
yTest = to_categorical(yTest, 2)

# Split training dataset into training and validation
x_train, x_val, y_train, y_val = train_test_split(df_train, y, test_size=0.3, random_state=42)

x_train = x_train.astype(np.float32)
x_val   = x_val.astype(np.float32)

# %% [markdown]
# ## Carga del modelo
#
# Aqui se carga el modelo y los datos de entrenamiento

# %%
import os

# Ver o que existe em pyTraining/
print(os.listdir("."))

# Se existir uma pasta models/, ver o que tem dentro
if os.path.exists("models"):
    print(os.listdir("models"))
teacher_model = keras.models.load_model("models/teacherModel_GN_GICM.h5")
teacher_model.summary()
# Out:
# ['paper.pdf', 'P3_Compilation.ipynb', 'vivado_src', 'P2_NN_Pruning.ipynb', 'requirements.txt', 'P1_TF_Training.ipynb', 'Vivado_Impl.md', 'images', 'dataset', 'models', 'vitis_src', 'udma_script', '.gitignore', '.python-version', 'P0_Dataset.ipynb', 'requirements_mac.txt', 'src']
# ['teacherModel_GN_GICM.h5']
# Model: "teacher_MLP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc1 (Dense)                 (None, 10)                1620
#
#  relu1 (Activation)          (None, 10)                0
#
#  fc2 (Dense)                 (None, 5)                 55
#
#  relu2 (Activation)          (None, 5)                 0
#
#  fc3 (Dense)                 (None, 7)                 42
#
#  relu3 (Activation)          (None, 7)                 0
#
#  dropout (Dropout)           (None, 7)                 0
#
#  fc4 (Dense)                 (None, 5)                 40
#
#  relu4 (Activation)          (None, 5)                 0
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  fc5 (Dense)                 (None, 6)                 36
#
#  relu5 (Activation)          (None, 6)                 0
#
#  dropout_2 (Dropout)         (None, 6)                 0
#
#  output (Dense)              (None, 2)                 14
#
#  activationOutput (Activati  (None, 2)                 0
#  on)
#
# =================================================================
# Total params: 1807 (7.06 KB)
# Trainable params: 1807 (7.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Podado, Pruning
#
# Aqui se hara el proceso de podado y reduccion de complejidad del modelo para el modelo entrenado. Primero se cargara el modelo previamente guardado

# %% [markdown]
# ![Distilation](images/distillation.png)

# %%
epochs = 100
lr = 0.001
loss = 'categorical_crossentropy'
op = Adam(learning_rate=lr)
metrics = ['accuracy']
batch = 64
val_split = 0.2

final_sparsity = 0.3 # percentage of weights pruned

pruning_params = {
                 'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(
                    initial_sparsity=0, 
                    final_sparsity=final_sparsity, 
                    begin_step=0, 
                    end_step=1000
                 )
                 }
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
callbacks = [
    # tf.keras.callbacks.EarlyStopping(
    #     monitor='val_loss',
    #     patience=2,
    #     verbose=1,
    #     restore_best_weights=True
    # ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', #'val_loss',
        factor=0.4,
        patience=3,
        verbose=1
    ), 
    pruning_callbacks.UpdatePruningStep()
]

# %% [markdown]
# ### Podado del modelo

# %%
modelP = tfmot.sparsity.keras.prune_low_magnitude(teacher_model, **pruning_params)
modelP.compile(optimizer=op, loss=loss, metrics=metrics)
# Out:
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
history_P = modelP.fit(x=x_train, y=y_train,
                       validation_split=val_split,
                       batch_size=batch, 
                       epochs=epochs,
                       callbacks= callbacks,
                       verbose=1
                       )
# Out:
# Epoch 1/100
# 158/158 [==============================] - 2s 2ms/step - loss: 0.1386 - accuracy: 0.9762 - val_loss: 0.0652 - val_accuracy: 0.9917 - lr: 0.0010
# Epoch 2/100
# 158/158 [==============================] - 0s 894us/step - loss: 0.1147 - accuracy: 0.9798 - val_loss: 0.0624 - val_accuracy: 0.9917 - lr: 0.0010
# Epoch 3/100
# 158/158 [==============================] - 0s 881us/step - loss: 0.1059 - accuracy: 0.9798 - val_loss: 0.0590 - val_accuracy: 0.9921 - lr: 0.0010
# Epoch 4/100
# 158/158 [==============================] - 0s 704us/step - loss: 0.0955 - accuracy: 0.9845 - val_loss: 0.0606 - val_accuracy: 0.9909 - lr: 0.0010
# Epoch 5/100
# 158/158 [==============================] - 0s 704us/step - loss: 0.0951 - accuracy: 0.9817 - val_loss: 0.0574 - val_accuracy: 0.9933 - lr: 0.0010
# Epoch 6/100
# 158/158 [==============================] - 0s 720us/step - loss: 0.0966 - accuracy: 0.9837 - val_loss: 0.0553 - val_accuracy: 0.9917 - lr: 0.0010
# Epoch 7/100
# 158/158 [==============================] - 0s 701us/step - loss: 0.0958 - accuracy: 0.9839 - val_loss: 0.0582 - val_accuracy: 0.9909 - lr: 0.0010
# Epoch 8/100
# 158/158 [==============================] - 0s 682us/step - loss: 0.0965 - accuracy: 0.9829 - val_loss: 0.0542 - val_accuracy: 0.9925 - lr: 0.0010
# Epoch 9/100
# 158/158 [==============================] - 0s 665us/step - loss: 0.0955 - accuracy: 0.9832 - val_loss: 0.0517 - val_accuracy: 0.9917 - lr: 0.0010
# Epoch 10/100
# 158/158 [==============================] - 0s 943us/step - loss: 0.0925 - accuracy: 0.9837 - val_loss: 0.0526 - val_accuracy: 0.9929 - lr: 0.0010
# Epoch 11/100
# 158/158 [==============================] - 0s 730us/step - loss: 0.0924 - accuracy: 0.9839 - val_loss: 0.0578 - val_accuracy: 0.9905 - lr: 0.0010
# Epoch 12/100
#  81/158 [==============>...............] - ETA: 0s - loss: 0.0865 - accuracy: 0.9850
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 158/158 [==============================] - 0s 744us/step - loss: 0.0934 - accuracy: 0.9836 - val_loss: 0.0566 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 13/100
# 158/158 [==============================] - 0s 686us/step - loss: 0.0901 - accuracy: 0.9837 - val_loss: 0.0565 - val_accuracy: 0.9905 - lr: 4.0000e-04
# Epoch 14/100
# 158/158 [==============================] - 0s 692us/step - loss: 0.0885 - accuracy: 0.9854 - val_loss: 0.0534 - val_accuracy: 0.9937 - lr: 4.0000e-04
# Epoch 15/100
#  90/158 [================>.............] - ETA: 0s - loss: 0.0848 - accuracy: 0.9870
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.
- val_loss: 0.0490 - val_accuracy: 0.9940 - lr: 4.5036e-14
# Epoch 98/100
#  95/158 [=================>............] - ETA: 0s - loss: 0.0850 - accuracy: 0.9852
# Epoch 98: ReduceLROnPlateau reducing learning rate to 1.801440127711246e-14.
# 158/158 [==============================] - 0s 666us/step - loss: 0.0833 - accuracy: 0.9853 - val_loss: 0.0490 - val_accuracy: 0.9940 - lr: 4.5036e-14
# Epoch 99/100
# 158/158 [==============================] - 0s 663us/step - loss: 0.0790 - accuracy: 0.9860 - val_loss: 0.0490 - val_accuracy: 0.9940 - lr: 1.8014e-14
# Epoch 100/100
# 158/158 [==============================] - 0s 667us/step - loss: 0.0840 - accuracy: 0.9865 - val_loss: 0.0490 - val_accuracy: 0.9940 - lr: 1.8014e-14

# %%
print(history_P.history.keys())

## Plot for accuracy
plt.figure(figsize=(15,3))
plt.plot(history_P.history['accuracy'])
plt.plot(history_P.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
plt.figure()

## Plot for loss
plt.figure(figsize=(15,3))
plt.plot(history_P.history['loss'])
plt.plot(history_P.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# ### Confusion matrix
#
# Matriz de confusion despues del podado

# %%
# Obtain the confusion matrix using the testing dataset 
y_pred_probs = modelP.predict(dfTest)
y_pred = np.argmax(y_pred_probs, axis=1)

# Since y_test is one-hot encoded, you need to convert it back to class indices
y_true = np.argmax(yTest, axis=1)  # Convert one-hot encoded labels to class indices

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title('Confusion Matrix - Teacher model after pruning')
plt.show()
# Out:
# 60/60 [==============================] - 0s 365us/step

# %% [markdown]
# ### Paso obligatorio después del pruning
#
# Antes de exportar el modelo debes eliminar los wrappers:

# %%
modelP = strip_pruning(modelP)

# %% [markdown]
# ---
#
# ## Cuantizacion (QAT)
#
# Aqui se aplicara la cuantizacion para reducir el tamaño y resolucion de la red

# %%
## Estrategia de cuantizacion

## Definicion del numero de bits para kernel, bias, y activacion.
# 8-bits

neurons_teacher = [10, 5, 7, 5, 6]

kernelQ      = "quantized_bits(8,4,alpha=1)"
biasQ        = "quantized_bits(8,4,alpha=1)"
activationQ  = "quantized_bits(8,4,alpha=1)"

modelQAT = Sequential(
    [
        QDense(neurons_teacher[0], name='input', input_shape=(161,),
                           kernel_quantizer=kernelQ, bias_quantizer=biasQ,
                           kernel_initializer='lecun_uniform'),
                    QActivation(activation=activationQ, name='relu0'),
                    # Dropout(0.1),

                    QDense(neurons_teacher[1], name='fc1', 
                           kernel_quantizer=kernelQ, bias_quantizer=biasQ,
                           kernel_initializer='lecun_uniform'),
                    QActivation(activation=activationQ, name='relu1'),
                    # Dropout(0.1),

                    QDense(neurons_teacher[2], name='fc2',
                           kernel_quantizer=kernelQ, bias_quantizer=biasQ,
                           kernel_initializer='lecun_uniform'),
                    QActivation(activation=activationQ, name='relu2'),
                    Dropout(0.1),

                    QDense(neurons_teacher[3], name='fc3',
                           kernel_quantizer=kernelQ, bias_quantizer=biasQ,
                           kernel_initializer='lecun_uniform'),
                    QActivation(activation=activationQ, name='relu3'), 
                    Dropout(0.2),
                
                    QDense(neurons_teacher[4], name='fc4',
                           kernel_quantizer=kernelQ, bias_quantizer=biasQ,
                           kernel_initializer='lecun_uniform'),
                    QActivation(activation=activationQ, name='relu4'), 
                    Dropout(0.2),
                
                    QDense(2, name='output',
                           kernel_quantizer= kernelQ, bias_quantizer= biasQ,
                           kernel_initializer='lecun_uniform'),
                    Activation(activation='sigmoid', name='sigmoid')       
    ], 
    name = "QuantizedModel",
)

# %%
modelQAT.summary()
# Out:
# Model: "QuantizedModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (QDense)              (None, 10)                1620
#
#  relu0 (QActivation)         (None, 10)                0
#
#  fc1 (QDense)                (None, 5)                 55
#
#  relu1 (QActivation)         (None, 5)                 0
#
#  fc2 (QDense)                (None, 7)                 42
#
#  relu2 (QActivation)         (None, 7)                 0
#
#  dropout (Dropout)           (None, 7)                 0
#
#  fc3 (QDense)                (None, 5)                 40
#
#  relu3 (QActivation)         (None, 5)                 0
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  fc4 (QDense)                (None, 6)                 36
#
#  relu4 (QActivation)         (None, 6)                 0
#
#  dropout_2 (Dropout)         (None, 6)                 0
#
#  output (QDense)             (None, 2)                 14
#
#  sigmoid (Activation)        (None, 2)                 0
#
# =================================================================
# Total params: 1807 (7.06 KB)
# Trainable params: 1807 (7.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Creacion del modelo cuantizado
#
# Aqui se realiza el entrenamiento

# %%
callbacks = [
    # tf.keras.callbacks.EarlyStopping(
    #     monitor='val_loss',
    #     patience=2,
    #     verbose=1,
    #     restore_best_weights=True
    # ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', #'val_loss',
        factor=0.4,
        patience=3,
        verbose=1
    ), 
    pruning_callbacks.UpdatePruningStep()
]

# %%
epochs = 150
lr = 0.0001
loss = 'binary_crossentropy'
op = Adam(learning_rate=lr)
metrics = ['accuracy']
batch = 32  
val_split = 0.2

modelQAT.compile(optimizer=op, loss=loss, metrics=metrics)

history_QAT = modelQAT.fit(x=x_train, y=y_train,
                       validation_split=val_split,
                       epochs=epochs,
                       batch_size=batch,
                       callbacks= callbacks,
                       verbose=1
                       )
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/150
# 315/315 [==============================] - 1s 1ms/step - loss: 0.5668 - accuracy: 0.7690 - val_loss: 0.3778 - val_accuracy: 0.9738 - lr: 1.0000e-04
# Epoch 2/150
# 315/315 [==============================] - 0s 515us/step - loss: 0.2662 - accuracy: 0.9629 - val_loss: 0.0893 - val_accuracy: 0.9905 - lr: 1.0000e-04
# Epoch 3/150
# 315/315 [==============================] - 0s 511us/step - loss: 0.1224 - accuracy: 0.9808 - val_loss: 0.0405 - val_accuracy: 0.9905 - lr: 1.0000e-04
# Epoch 4/150
# 315/315 [==============================] - 0s 511us/step - loss: 0.0873 - accuracy: 0.9836 - val_loss: 0.0329 - val_accuracy: 0.9905 - lr: 1.0000e-04
# Epoch 5/150
# 315/315 [==============================] - 0s 515us/step - loss: 0.0719 - accuracy: 0.9848 - val_loss: 0.0350 - val_accuracy: 0.9929 - lr: 1.0000e-04
# Epoch 6/150
# 315/315 [==============================] - 0s 652us/step - loss: 0.0595 - accuracy: 0.9867 - val_loss: 0.0345 - val_accuracy: 0.9913 - lr: 1.0000e-04
# Epoch 7/150
# 242/315 [======================>.......] - ETA: 0s - loss: 0.0598 - accuracy: 0.9859
# Epoch 7: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
#
- val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 2.9515e-18
# Epoch 108/150
# 315/315 [==============================] - 0s 515us/step - loss: 0.0556 - accuracy: 0.9896 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 2.9515e-18
# Epoch 109/150
# 241/315 [=====================>........] - ETA: 0s - loss: 0.0631 - accuracy: 0.9886
# Epoch 109: ReduceLROnPlateau reducing learning rate to 1.1805916267509e-18.
# 315/315 [==============================] - 0s 516us/step - loss: 0.0612 - accuracy: 0.9891 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 2.9515e-18
# Epoch 110/150
# 315/315 [==============================] - 0s 533us/step - loss: 0.0547 - accuracy: 0.9893 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.1806e-18
# Epoch 111/150
# 315/315 [==============================] - 0s 513us/step - loss: 0.0561 - accuracy: 0.9894 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.1806e-18
# Epoch 112/150
# 238/315 [=====================>........] - ETA: 0s - loss: 0.0601 - accuracy: 0.9887
# Epoch 112: ReduceLROnPlateau reducing learning rate to 4.722366672439722e-19.
# 315/315 [==============================] - 0s 518us/step - loss: 0.0570 - accuracy: 0.9890 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.1806e-18
# Epoch 113/150
# 315/315 [==============================] - 0s 513us/step - loss: 0.0577 - accuracy: 0.9896 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 4.7224e-19
# Epoch 114/150
# 315/315 [==============================] - 0s 515us/step - loss: 0.0532 - accuracy: 0.9894 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 4.7224e-19
# Epoch 115/150
# 240/315 [=====================>........] - ETA: 0s - loss: 0.0587 - accuracy: 0.9900
# Epoch 115: ReduceLROnPlateau reducing learning rate to 1.8889467516939503e-19.
# 315/315 [==============================] - 0s 517us/step - loss: 0.0600 - accuracy: 0.9895 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 4.7224e-19
# Epoch 116/150
# 315/315 [==============================] - 0s 512us/step - loss: 0.0576 - accuracy: 0.9894 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.8889e-19
# Epoch 117/150
# 315/315 [==============================] - 0s 515us/step - loss: 0.0527 - accuracy: 0.9895 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.8889e-19
# Epoch 118/150
# 239/315 [=====================>........] - ETA: 0s - loss: 0.0559 - accuracy: 0.9898
# Epoch 118: ReduceLROnPlateau reducing learning rate to 7.555787213570954e-20.
# 315/315 [==============================] - 0s 517us/step - loss: 0.0560 - accuracy: 0.9895 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.8889e-19
# Epoch 119/150
# 315/315 [==============================] - 0s 643us/step - loss: 0.0543 - accuracy: 0.9893 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 7.5558e-20
# Epoch 120/150
# 315/315 [==============================] - 0s 523us/step - loss: 0.0548 - accuracy: 0.9894 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 7.5558e-20
# Epoch 121/150
# 240/315 [=====================>........] - ETA: 0s - loss: 0.0597 - accuracy: 0.9887
# Epoch 121: ReduceLROnPlateau reducing learning rate to 3.022314782030805e-20.
# 315/315 [==============================] - 0s 515us/step - loss: 0.0583 - accuracy: 0.9890 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 7.5558e-20
# Epoch 122/150
# 315/315 [==============================] - 0s 503us/step - loss: 0.0576 - accuracy: 0.9892 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 3.0223e-20
# Epoch 123/150
# 315/315 [==============================] - 0s 503us/step - loss: 0.0571 - accuracy: 0.9892 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 3.0223e-20
# Epoch 124/150
# 247/315 [======================>.......] - ETA: 0s - loss: 0.0539 - accuracy: 0.9894
# Epoch 124: ReduceLROnPlateau reducing learning rate to 1.2089258869629279e-20.
# 315/315 [==============================] - 0s 504us/step - loss: 0.0558 - accuracy: 0.9892 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr:
- val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.2379e-22
# Epoch 142/150
# 241/315 [=====================>........] - ETA: 0s - loss: 0.0542 - accuracy: 0.9887
# Epoch 142: ReduceLROnPlateau reducing learning rate to 4.9517609338644756e-23.
# 315/315 [==============================] - 0s 514us/step - loss: 0.0581 - accuracy: 0.9887 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.2379e-22
# Epoch 143/150
# 315/315 [==============================] - 0s 514us/step - loss: 0.0560 - accuracy: 0.9893 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 4.9518e-23
# Epoch 144/150
# 315/315 [==============================] - 0s 515us/step - loss: 0.0539 - accuracy: 0.9889 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 4.9518e-23
# Epoch 145/150
# 314/315 [============================>.] - ETA: 0s - loss: 0.0575 - accuracy: 0.9896
# Epoch 145: ReduceLROnPlateau reducing learning rate to 1.9807043987893394e-23.
# 315/315 [==============================] - 0s 630us/step - loss: 0.0573 - accuracy: 0.9896 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 4.9518e-23
# Epoch 146/150
# 315/315 [==============================] - 0s 519us/step - loss: 0.0574 - accuracy: 0.9894 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.9807e-23
# Epoch 147/150
# 315/315 [==============================] - 0s 514us/step - loss: 0.0555 - accuracy: 0.9898 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.9807e-23
# Epoch 148/150
# 241/315 [=====================>........] - ETA: 0s - loss: 0.0562 - accuracy: 0.9888
# Epoch 148: ReduceLROnPlateau reducing learning rate to 7.922817847592847e-24.
# 315/315 [==============================] - 0s 516us/step - loss: 0.0570 - accuracy: 0.9894 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 1.9807e-23
# Epoch 149/150
# 315/315 [==============================] - 0s 530us/step - loss: 0.0571 - accuracy: 0.9892 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 7.9228e-24
# Epoch 150/150
# 315/315 [==============================] - 0s 512us/step - loss: 0.0523 - accuracy: 0.9884 - val_loss: 0.0347 - val_accuracy: 0.9909 - lr: 7.9228e-24

# %%
print(history_QAT.history.keys())

## Plot for accuracy
plt.figure(figsize=(15,3))
plt.plot(history_QAT.history['accuracy'])
plt.plot(history_QAT.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
plt.figure()

## Plot for loss
plt.figure(figsize=(15,3))
plt.plot(history_QAT.history['loss'])
plt.plot(history_QAT.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# Obtain the confusion matrix using the testing dataset 
y_pred_probs = modelQAT.predict(dfTest)
y_pred = np.argmax(y_pred_probs, axis=1)

# Since y_test is one-hot encoded, you need to convert it back to class indices
y_true = np.argmax(yTest, axis=1)  # Convert one-hot encoded labels to class indices

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title('Confusion Matrix - Teacher model obtained through quantization aware training')
plt.show()
# Out:
# 60/60 [==============================] - 0s 386us/step

# %% [markdown]
# ### Guardado del modelo podado y cuantizado

# %%
# If needed, save the teacher QAT model [uncomment the following line]
modelQAT.save('models/teacherQATModel_GN_GICM.h5')
# Out:
# /opt/anaconda3/envs/hls4ml/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ---
#
# # Entrenamiento del modelo Student
#
# Para obtener el modelo reducido que será implementado en la FPGA (llamado en adelante red estudiante), se empleará un enfoque de aprendizaje por destilación de conocimiento (**KD**).
#
# En este método, el modelo maestro transfiere lo aprendido al modelo estudiante.
#
# El modelo estudiante se define aplicando cuantización y poda.
#
# En este proyecto se fijaron:
#
# - 8 bits para la cuantización
# - 50% de sparsity (poda de la mitad de los pesos).
#
# Para la cuantización se utiliza QKeras, una librería especializada para redes neuronales cuantizadas y optimizadas para hardware.
#
# **Referencia sobre QKeras**:
# Coelho et al. (2020). Ultra low-latency, low-area inference accelerators using heterogeneous deep quantization with QKeras and hls4ml. arXiv:2006.10159.

# %% [markdown]
# ### Hiperparametros para el modelo Student

# %% [markdown]
# ![Distilation](images/studentArchitecture.png)

# %%
# Define the hyperparameters for the student model
lr = 0.001
neurons_student = [6, 4, 2, 4, 3]

# %%
def student_topology(neurons_student):
    
    '''
    Model to be trained. Defined with quantization strategies. 
    Input: hyperparams. (bestHP)
    Output: compressed model (studentQ_MLP). 

    '''
    ######## ---------------------------  Model definition - 1D STUDENT -----------------------------------------

    # Number of bits 
    ## 4-bits
    kernelQ_4b = "quantized_bits(4,2,alpha=1)"
    biasQ_4b = "quantized_bits(4,2,alpha=1)"
    activationQ_4b = 'quantized_bits(4, 0)'

    ## 8-bits
    kernelQ = "quantized_bits(8,4,alpha=1)"
    biasQ = "quantized_bits(8,4,alpha=1)"
    activationQ = 'quantized_bits(8,4)'
    
    ## 16-bits
    kernelQ_16b = "quantized_bits(16,6,alpha=1)"
    biasQ_16b = "quantized_bits(16,6,alpha=1)"
    activationQ_16b = 'quantized_bits(16,6)'
    
    studentQ_MLP = keras.Sequential(
            [   
                Input(shape=(161,), name='inputLayer'),
                QDense(neurons_student[0], name='fc1',
                        kernel_quantizer= kernelQ, bias_quantizer= biasQ,
                        kernel_initializer='lecun_uniform'),
                QActivation(activation= activationQ ,  name='relu0'),
                Dropout(0.1),
                    
                QDense(neurons_student[1], name='fc2',
                        kernel_quantizer=kernelQ, bias_quantizer=biasQ,
                        kernel_initializer='lecun_uniform'),
                QActivation(activation=activationQ, name='relu1'), 
                Dropout(0.1),
                

                QDense(neurons_student[2], name='fc3',
                        kernel_quantizer=kernelQ, bias_quantizer=biasQ,
                        kernel_initializer='lecun_uniform'),
                QActivation(activation=activationQ, name='relu2'), 
                Dropout(0.1),

                QDense(neurons_student[3], name='fc4',
                        kernel_quantizer=kernelQ, bias_quantizer=biasQ,
                        kernel_initializer='lecun_uniform'),
                QActivation(activation=activationQ, name='relu3'), 
                Dropout(0.2),

                QDense(neurons_student[4], name='fc5',
                       kernel_quantizer=kernelQ, bias_quantizer=biasQ,
                       kernel_initializer='lecun_uniform'),
                QActivation(activation=activationQ, name='relu4'), 
                Dropout(0.2),
               
                QDense(2, name='output',
                        kernel_quantizer= kernelQ_16b, bias_quantizer= biasQ_16b,
                        kernel_initializer='lecun_uniform'),
                Activation(activation='sigmoid', name='outputActivation')

                
            ],
            name="studentMLP",
        )


    return studentQ_MLP

# %% [markdown]
# ### Construccion del modelo

# %%
# Build student model with pruning strategy

def build_student(student_neurons, x_train, batch_size=64, epochs=200):

    '''
    Build pruned student model
    '''

    qmodel = student_topology(student_neurons)

    steps_per_epoch = np.ceil(len(x_train) / batch_size)
    end_step = steps_per_epoch * epochs

    pruning_params = {
        "pruning_schedule": tfmot.sparsity.keras.PolynomialDecay(
            initial_sparsity=0.0,
            final_sparsity=0.5,
            begin_step=0,
            end_step=end_step
        )
    }

    studentQ = tfmot.sparsity.keras.prune_low_magnitude(
        qmodel,
        **pruning_params
    )

    return studentQ

# %% [markdown]
# ---
#
# ### Compilacion del modelo Student para KD y QAT
#
# Compilacion para destilacion de conocimiento y cuantizacion

# %%
studentQ = build_student(neurons_student, x_train)
studentQ.summary()
# Out:
# Model: "studentMLP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prune_low_magnitude_fc1 (P  (None, 6)                 1940
#  runeLowMagnitude)
#
#  prune_low_magnitude_relu0   (None, 6)                 1
#  (PruneLowMagnitude)
#
#  prune_low_magnitude_dropou  (None, 6)                 1
#  t_3 (PruneLowMagnitude)
#
#  prune_low_magnitude_fc2 (P  (None, 4)                 54
#  runeLowMagnitude)
#
#  prune_low_magnitude_relu1   (None, 4)                 1
#  (PruneLowMagnitude)
#
#  prune_low_magnitude_dropou  (None, 4)                 1
#  t_4 (PruneLowMagnitude)
#
#  prune_low_magnitude_fc3 (P  (None, 2)                 20
#  runeLowMagnitude)
#
#  prune_low_magnitude_relu2   (None, 2)                 1
#  (PruneLowMagnitude)
#
#  prune_low_magnitude_dropou  (None, 2)                 1
#  t_5 (PruneLowMagnitude)
#
#  prune_low_magnitude_fc4 (P  (None, 4)                 22
#  runeLowMagnitude)
#
#  prune_low_magnitude_relu3   (None, 4)                 1
#  (PruneLowMagnitude)
#
#  prune_low_magnitude_dropou  (None, 4)                 1
#  t_6 (PruneLowMagnitude)
#
#  prune_low_magnitude_fc5 (P  (None, 3)                 29
#  runeLowMagnitude)
#
#  prune_low_magnitude_relu4   (None, 3)                 1
#  (PruneLowMagnitude)
#
#  prune_low_magnitude_dropou  (None, 3)                 1
#  t_7 (PruneLowMagnitude)
#
#  prune_low_magnitude_output  (None, 2)                 16
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_output  (None, 2)                 1
#  Activation (PruneLowMagnit
#  ude)
#
# =================================================================
# Total params: 2092 (8.24 KB)
# Trainable params: 1045 (4.08 KB)
# Non-trainable params: 1047 (4.16 KB)
# _________________________________________________________________

# %%
distilled_student = Distiller(student=studentQ, teacher=modelQAT)
adam = Adam(learning_rate=lr)
train_labels = np.argmax(y_train, axis=1)

distilled_student.compile(
        optimizer=adam,
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
        student_loss_fn=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        distillation_loss_fn=keras.losses.KLDivergence(),
        alpha=0.1,
        temperature=10,
    )
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### Entrenamiento del modelo Student

# %%
callbacks = [
     tf.keras.callbacks.EarlyStopping(
         monitor='val_student_loss',
        patience=10,
         verbose=1,
         restore_best_weights=True
     ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_student_loss', #'val_loss',
        factor=0.3,
        patience=3,
        verbose=1
    ), 
    pruning_callbacks.UpdatePruningStep(),
]

history_student = distilled_student.fit(
    x=x_train,
    y=train_labels,
    batch_size=64,
    epochs=200,
    validation_split=0.2,
    callbacks=callbacks,
)
# Out:
# Epoch 1/200
# 158/158 [==============================] - 0s 1ms/step - sparse_categorical_accuracy: 0.9328 - student_loss: 0.2542 - distillation_loss: 5.1521e-04 - val_sparse_categorical_accuracy: 0.9917 - val_student_loss: 0.0815 - lr: 1.0301e-37
# Epoch 2/200
# 158/158 [==============================] - 0s 1ms/step - sparse_categorical_accuracy: 0.9297 - student_loss: 0.2490 - distillation_loss: 5.1102e-04 - val_sparse_categorical_accuracy: 0.9917 - val_student_loss: 0.0804 - lr: 1.0301e-37
# Epoch 3/200
# 158/158 [==============================] - 0s 887us/step - sparse_categorical_accuracy: 0.9311 - student_loss: 0.2492 - distillation_loss: 5.0888e-04 - val_sparse_categorical_accuracy: 0.9917 - val_student_loss: 0.0804 - lr: 1.0301e-37
# Epoch 4/200
# 158/158 [==============================] - 0s 1ms/step - sparse_categorical_accuracy: 0.9330 - student_loss: 0.2507 - distillation_loss: 5.1078e-04 - val_sparse_categorical_accuracy: 0.9917 - val_student_loss: 0.0804 - lr: 1.0301e-37
# Epoch 5/200
# 130/158 [=======================>......] - ETA: 0s - sparse_categorical_accuracy: 0.9305 - student_loss: 0.2526 - distillation_loss: 5.1157e-04
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.0903164619154e-38.
# 158/158 [==============================] - 0s 1ms/step - sparse_categorical_accuracy: 0.9309 - student_loss: 0.2516 - distillation_loss: 5.1172e-04 - val_sparse_categorical_accuracy: 0.9917 - val_student_loss: 0.0804 - lr: 1.0301e-37
# Epoch 6/200
# 158/158 [==============================] - 0s 934us/step - sparse_categorical_accuracy: 0.9367 - student_loss: 0.2469 - distillation_loss: 5.0525e-04 - val_sparse_categorical_accuracy: 0.9917 - val_student_loss: 0.0804 - lr: 3.0903e-38
# Epoch 7/200
# 158/158 [==============================] - 0s 920us/step - sparse_categorical_accuracy: 0.9290 - student_loss: 0.2451 - distillation_loss: 5.0288e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0708 - lr: 3.0903e-38
# Epoch 8/200
# 158/158 [==============================] - 0s 888us/step - sparse_categorical_accuracy: 0.9366 - student_loss: 0.2401 - distillation_loss: 4.9707e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0708 - lr: 3.0903e-38
# Epoch 9/200
# 158/158 [==============================] - 0s 937us/step - sparse_categorical_accuracy: 0.9398 - student_loss: 0.2374 - distillation_loss: 4.9113e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0708 - lr: 3.0903e-38
# Epoch 10/200
# 128/158 [=======================>......] - ETA: 0s - sparse_categorical_accuracy: 0.9362 - student_loss: 0.2425 - distillation_loss: 4.9827e-04
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.270949722057831e-39.
# 158/158 [==============================] - 0s 930us/step - sparse_categorical_accuracy: 0.9356 - student_loss: 0.2434 - distillation_loss: 4.9775e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0708 - lr: 3.0903e-38
# Epoch 11/200
# 158/158 [==============================] - 0s 890us/step - sparse_categorical_accuracy: 0.9345 - student_loss: 0.2414 - distillation_loss: 5.0095e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0708 - lr: 9.2710e-39
# Epoch 12/200
# 158/158 [==============================] - 0s 899us/step - sparse_categorical_accuracy: 0.9371 - student_loss: 0.2406 - distillation_loss: 4.9571e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0708 - lr: 9.2710e-39
# Epoch 13/200
# 129/158 [=======================>......] - ETA: 0s - sparse_categorical_accuracy: 0.9336 - student_loss: 0.2440 - distillation_loss: 4.9938e-04
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.781285000695257e-39.
# 158/158 [==============================] - 0s 926us/step - sparse_categorical_accuracy: 0.9324 - student_loss: 0.2439 - distillation_loss: 4.9931e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0708 - lr: 9.2710e-39
# Epoch 14/200
# 158/158 [==============================] - 0s 897us/step - sparse_categorical_accuracy: 0.9355 - student_loss: 0.2416 - distillation_loss: 5.0054e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0709 - lr: 2.7813e-39
# Epoch 15/200
# 158/158 [==============================] - 0s 889us/step - sparse_categorical_accuracy: 0.9377 - student_loss: 0.2413 - distillation_loss: 4.9780e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0709 - lr: 2.7813e-39
# Epoch 16/200
# 135/158 [========================>.....] - ETA: 0s - sparse_categorical_accuracy: 0.9374 - student_loss: 0.2394 - distillation_loss: 4.9542e-04
# Epoch 16: ReduceLROnPlateau reducing learning rate to 8.343853740917153e-40.
# 158/158 [==============================] - 0s 893us/step - sparse_categorical_accuracy: 0.9370 - student_loss: 0.2384 - distillation_loss: 4.9274e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0709 - lr: 2.7813e-39
# Epoch 17/200
# 135/158 [========================>.....] - ETA: 0s - sparse_categorical_accuracy: 0.9370 - student_loss: 0.2414 - distillation_loss: 4.9925e-04Restoring model weights from the end of the best epoch: 7.
# 158/158 [==============================] - 0s 914us/step - sparse_categorical_accuracy: 0.9374 - student_loss: 0.2413 - distillation_loss: 4.9886e-04 - val_sparse_categorical_accuracy: 0.9937 - val_student_loss: 0.0709 - lr: 8.3438e-40
# Epoch 17: early stopping

# %%
print(history_student.history.keys())

## Plot for accuracy
plt.figure(figsize=(15,3))
plt.plot(history_student.history['sparse_categorical_accuracy'])
plt.plot(history_student.history['val_sparse_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
plt.figure()

## Plot for loss
plt.figure(figsize=(15,3))
plt.plot(history_student.history['student_loss'])
plt.plot(history_student.history['val_student_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['sparse_categorical_accuracy', 'student_loss', 'distillation_loss', 'val_sparse_categorical_accuracy', 'val_student_loss', 'lr'])

# %%
# Obtain the confusion matrix using the testing dataset 
y_pred_probs = distilled_student.student.predict(dfTest)
y_pred = np.argmax(y_pred_probs, axis=1)

# Since y_test is one-hot encoded, you need to convert it back to class indices
y_true = np.argmax(yTest, axis=1)  # Convert one-hot encoded labels to class indices

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title('Confusion Matrix - Student model Q, P, and KD')
plt.show()
# Out:
# 60/60 [==============================] - 0s 395us/step

# %% [markdown]
# ### Prueba de predicción individual
#
# Prueba el modelo con entradas individuales.
#
# La variable indexPrediction corresponde al índice de la señal en el conjunto de datos de prueba. Puedes cambiar este número para observar cómo el modelo basado en ML predice para entradas específicas.

# %%
# Index of the signal in the testing dataset
indexPrediction = 405

x_input = dfTest.iloc[indexPrediction]
y_label = yTest[indexPrediction]

inputPred = array([x_input])

y_pred = distilled_student.student.predict(inputPred) 
print("> Input %s -> Predicted = %s | " % (y_label, y_pred))

plt.figure(figsize=(15,3))
plt.xlabel('Samples', fontsize=11)
plt.ylabel('Amplitude', fontsize=11)
plt.grid(True, alpha=1.0)
plt.plot(x_input.values,  label="Signal 1", color='navy', markersize=7, lw=1)

plt.title('Signal used for inference - Pulse: %s, Label: %s, Prediction: %s' % (indexPrediction, y_label, y_pred))
# Out:
# 1/1 [==============================] - 0s 8ms/step
# > Input [1. 0.] -> Predicted = [[0.8110782  0.15674922]] |
# Text(0.5, 1.0, 'Signal used for inference - Pulse: 405, Label: [1. 0.], Prediction: [[0.8110782  0.15674922]]')

# %%
# Index of the signal in the testing dataset
indexPrediction = 200

x_input = dfTest.iloc[indexPrediction]
y_label = yTest[indexPrediction]

inputPred = array([x_input])

y_pred = distilled_student.student.predict(inputPred) 
print("> Input %s -> Predicted = %s | " % (y_label, y_pred))

plt.figure(figsize=(15,3))
plt.xlabel('Samples', fontsize=11)
plt.ylabel('Amplitude', fontsize=11)
plt.grid(True, alpha=1.0)
plt.plot(x_input.values,  label="Signal 1", color='navy', markersize=7, lw=1)

plt.title('Signal used for inference - Pulse: %s, Label: %s, Prediction: %s' % (indexPrediction, y_label, y_pred))
# Out:
# 1/1 [==============================] - 0s 12ms/step
# > Input [0. 1.] -> Predicted = [[0.36387292 0.6296038 ]] |
# Text(0.5, 1.0, 'Signal used for inference - Pulse: 200, Label: [0. 1.], Prediction: [[0.36387292 0.6296038 ]]')

# %% [markdown]
# ### Guardar el modelo Student

# %%
model_student = strip_pruning(distilled_student.student)
model_student.summary()

model_student.save('models/studentModel_GN_GICM.h5')
# Out:
# Model: "studentMLP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc1 (QDense)                (None, 6)                 972
#
#  relu0 (QActivation)         (None, 6)                 0
#
#  dropout_3 (Dropout)         (None, 6)                 0
#
#  fc2 (QDense)                (None, 4)                 28
#
#  relu1 (QActivation)         (None, 4)                 0
#
#  dropout_4 (Dropout)         (None, 4)                 0
#
#  fc3 (QDense)                (None, 2)                 10
#
#  relu2 (QActivation)         (None, 2)                 0
#
#  dropout_5 (Dropout)         (None, 2)                 0
#
#  fc4 (QDense)                (None, 4)                 12
#
#  relu3 (QActivation)         (None, 4)                 0
#
#  dropout_6 (Dropout)         (None, 4)                 0
#
#  fc5 (QDense)                (None, 3)                 15
#
#  relu4 (QActivation)         (None, 3)                 0
#
#  dropout_7 (Dropout)         (None, 3)                 0
#
#  output (QDense)             (None, 2)                 8
#
#  outputActivation (Activati  (None, 2)                 0
#  on)
#
# =================================================================
# Total params: 1045 (4.08 KB)
# Trainable params: 1045 (4.08 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /opt/anaconda3/envs/hls4ml/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ---
# **Autor**: Fabian Castaño
